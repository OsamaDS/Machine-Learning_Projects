# %%
import pandas as pd
pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv('taining_data.csv')

# %%
dataset.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1  12.247694    0.235294      0.75     0.418208  0.366344     1.0    1.0
# 1   2  12.109011    0.000000      0.75     0.495064  0.391317     1.0    1.0
# 2   3  12.317167    0.235294      0.75     0.434909  0.422359     1.0    1.0
# 3   4  11.849398    0.294118      0.75     0.388581  0.390295     1.0    1.0
# 4   5  12.429216    0.235294      0.75     0.513123  0.468761     1.0    1.0
#
#    LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0  0.000000     0.333333        1.0       0.00        0.0      0.636364
# 1  0.000000     0.333333        1.0       0.50        0.0      0.500000
# 2  0.333333     0.333333        1.0       0.00        0.0      0.636364
# 3  0.333333     0.333333        1.0       0.25        0.0      0.727273
# 4  0.333333     0.333333        1.0       0.50        0.0      1.000000
#
# ...

# %%
X=dataset.iloc[:,2:]
Y=dataset['SalePrice']

# %%
X.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0    0.235294      0.75     0.418208  0.366344     1.0    1.0  0.000000
# 1    0.000000      0.75     0.495064  0.391317     1.0    1.0  0.000000
# 2    0.235294      0.75     0.434909  0.422359     1.0    1.0  0.333333
# 3    0.294118      0.75     0.388581  0.390295     1.0    1.0  0.333333
# 4    0.235294      0.75     0.513123  0.468761     1.0    1.0  0.333333
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.333333        1.0       0.00        0.0      0.636364         0.4
# 1     0.333333        1.0       0.50        0.0      0.500000         0.2
# 2     0.333333        1.0       0.00        0.0      0.636364         0.4
# 3     0.333333        1.0       0.25        0.0      0.727273         0.4
# 4     0.333333        1.0       0.50        0.0      1.000000         0.4
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
Y.head()
# Out:
# 0    12.247694
# 1    12.109011
# 2    12.317167
# 3    11.849398
# 4    12.429216
# Name: SalePrice, dtype: float64

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
select_feature=SelectFromModel(Lasso(alpha=0.005, random_state=0)).fit(X,Y)

# %%
select_feature.get_support()
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True])

# %%
select_feature=X.columns[(select_feature.get_support())]
select_feature
# Out:
# Index(['MSSubClass', 'MSZoning', 'Neighborhood', 'OverallQual', 'YearRemodAdd',
#        'RoofStyle', 'BsmtQual', 'BsmtExposure', 'HeatingQC', 'CentralAir',
#        '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'KitchenQual', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'PavedDrive',
#        'SaleCondition'],
#       dtype='object')

# %%
X[select_feature].head()
# Out:
#    MSSubClass  MSZoning  Neighborhood  OverallQual  YearRemodAdd  RoofStyle  \
# 0    0.235294      0.75      0.636364     0.666667      0.883333        0.0
# 1    0.000000      0.75      0.500000     0.555556      0.433333        0.0
# 2    0.235294      0.75      0.636364     0.666667      0.866667        0.0
# 3    0.294118      0.75      0.727273     0.666667      0.333333        0.0
# 4    0.235294      0.75      1.000000     0.777778      0.833333        0.0
#
#    BsmtQual  BsmtExposure  HeatingQC  CentralAir  1stFlrSF  GrLivArea  \
# 0      0.75          0.25       1.00         1.0  0.356155   0.577712
# 1      0.75          1.00       1.00         1.0  0.503056   0.470245
# 2      0.75          0.50       1.00         1.0  0.383441   0.593095
# 3      0.50          0.25       0.75         1.0  0.399941   0.579157
# 4      0.75          0.75       1.00         1.0  0.466237   0.666523
#
#    BsmtFullBath  KitchenQual  Fireplaces  FireplaceQu  GarageType  \
# ...

# %%
X_final=X[select_feature]

# %%
X_final.shape
# Out:
# (1460, 21)

# %%
cor=dataset[['MSZoning','SalePrice']]
hm=cor.corr()
hm
# Out:
#            MSZoning  SalePrice
# MSZoning   1.000000   0.410575
# SalePrice  0.410575   1.000000

# %%
cor=dataset[['Neighborhood','SalePrice']]
hm=cor.corr()
hm
# Out:
#               Neighborhood  SalePrice
# Neighborhood      1.000000   0.739974
# SalePrice         0.739974   1.000000

# %%
cor=dataset[['OverallQual','SalePrice']]
hm=cor.corr()
hm
# Out:
#              OverallQual  SalePrice
# OverallQual     1.000000   0.817184
# SalePrice       0.817184   1.000000

# %%
cor=dataset[['YearRemodAdd','SalePrice']]
hm=cor.corr()
hm
# Out:
#               YearRemodAdd  SalePrice
# YearRemodAdd      1.000000   0.565608
# SalePrice         0.565608   1.000000

# %%
n_cor=dataset[['MSSubClass', 'MSZoning', 'Neighborhood', 'OverallQual', 'YearRemodAdd',
       'RoofStyle', 'BsmtQual', 'BsmtExposure', 'HeatingQC', 'CentralAir',
       '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'KitchenQual', 'Fireplaces',
       'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'PavedDrive',
       'SaleCondition','SalePrice']]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
ht=n_cor.corr()
T_C_F=ht.index
plt.figure(figsize=(20,20))
g=sns.heatmap(n_cor[T_C_F].corr(),annot=True,cmap='RdGy')

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
output=reg.fit(X,Y)

# %%
output.coef_
# Out:
# array([-2.60941694e-02,  7.20631666e-02,  1.57941686e-02,  2.47028327e-01,
#         1.49475000e-01,  1.37721338e-02, -3.58907398e-03,  5.79164327e-02,
#         2.90725052e-01,  2.21052964e-02, -3.49362120e-03,  2.03458040e-01,
#         6.27942136e-02,  1.00168787e-01, -2.06257520e-02, -2.21515138e-02,
#         4.93074630e-01,  3.10085225e-01,  1.30388055e-01,  2.65298895e-02,
#         6.99587986e-03, -6.82650842e-02,  7.06367589e-02, -4.30609810e-02,
#         1.07105569e-02,  2.26065632e-02,  2.66193123e-02,  3.26961304e-02,
#         4.39215183e-02,  5.39090431e-02,  1.65570900e-02,  5.02174997e-02,
#        -7.59418155e-03,  2.28669664e+12,  3.48890893e-02,  5.97198944e+11,
#         9.46442832e+11, -2.47549902e+12,  2.18920198e-02,  4.37975436e-02,
#         4.46019558e-02, -2.40073214e-02,  6.19102334e-01,  2.39809794e-01,
#         8.29010945e-02,  5.20511330e-01,  1.22819885e-01,  3.24805422e-02,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_new=dataset.iloc[:,2:]
Y_new=dataset['SalePrice']
x_train,x_test,y_train,y_test=train_test_split(X_new,Y_new,test_size=0.2,random_state=42)

# %%
regr=reg.fit(x_train,y_train)

# %%
y_hat=reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_hat)
# Out:
# 0.016659306065420855
